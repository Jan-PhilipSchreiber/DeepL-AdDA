# %% [markdown]
# <h3>Lifestyle sustainability, dataset</h3>

# %% [markdown]
# <b>Variables that can be dropped</b>

# %% [markdown]
# Participants id can be removed, physical activity and community involvement, missing 20% of data,
# but since 500 rows, prob fix with average values

# %% [markdown]
# <h4>Distributions</h4>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Homesize is balanced with high low ends, some smaller gaps, keep them in mind
